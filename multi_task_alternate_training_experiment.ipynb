# %% [markdown]
# # Configuration Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip show mmaction2
# Out:
# WARNING: Package(s) not found: mmaction2

# %%
# !pip install -U openmim

# %%
# !mim install mmengine
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 9.7 MB/s eta 0:00:00
# ...

# %%
# !mim install mmcv
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 MB 5.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2
# Out:
# /content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2

# %%
# !pip install -v -e .
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-axd02nj7/mmaction2.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-axd02nj7/mmaction2.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-axd02nj7/mmaction2.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 43.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.7 MB/s eta 0:00:00
# ...

# %%
# %cd ..

# %%
# !pip show mmaction2

# %%
# %cd /content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2

# %%
# %cd ..

# %%
# !pip install moviepy

# %% [markdown]
# # project train

# %% [markdown]
# # Task normal

# %% [markdown]
# ## base

# %% [markdown]
# ### epoch 30

# %%
# !python tools/train.py configs/recognition/swin/swin-base-goosebumps-multi-task-normal.py \
    --work-dir ../../../../../work_dirs/swin-base-goosebumps-multi-task-normal
# Out:
# 07/21 16:27:44 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 455629105
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-normal.py \
    ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/best_acc_top1_epoch_11.pth \
    --dump work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/results_best_acc_top1_epoch_11.pkl
# Out:
# python3: can't open file '/content/tools/test.py': [Errno 2] No such file or directory

# %%
# !python tools/train.py configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-normal.py \
    --resume ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/epoch_30.pth \
    --work-dir ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-normal
# Out:
# python3: can't open file '/content/tools/train.py': [Errno 2] No such file or directory

# %%
# !python tools/test.py configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-normal.py \
    ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/epoch_33.pth
    # --dump work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/results_60.pkl
# Out:
# python3: can't open file '/content/tools/test.py': [Errno 2] No such file or directory

# %%
# %cp -r ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/epoch_45.pth \
    work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/
# Out:
# cp: cannot stat '../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/epoch_45.pth': No such file or directory

# %%
# !python tools/analysis_tools/confusion_matrix.py \
    configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-normal.py \
    work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/results_60.pkl \
    --show
# Out:
# python3: can't open file '/content/tools/analysis_tools/confusion_matrix.py': [Errno 2] No such file or directory

# %%
# !python tools/analysis_tools/eval_metric.py \
    configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-normal.py \
    work_dirs/swin-base-kinetics400-goosebumps-project-task-normal/results_60.pkl
# Out:
# python3: can't open file '/content/tools/analysis_tools/eval_metric.py': [Errno 2] No such file or directory

# %%
# !python tools/analysis_tools/analyze_logs.py \
    plot_curve work_dirs/swin-base-kinetics400-goosebumps-project-task-normal//20240718_163657//20240718_163657.json \
     --keys loss_cls --legend loss_cls
# Out:
# python3: can't open file '/content/tools/analysis_tools/analyze_logs.py': [Errno 2] No such file or directory

# %% [markdown]
# # Task subclass

# %% [markdown]
# ## base

# %% [markdown]
# epoch 30

# %%
# !python tools/train.py configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-subclass.py \
    --work-dir ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass
# Out:
# 07/19 08:52:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1518091757
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-subclass.py \
    ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass/epoch_30.pth \
    --dump work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass/results_30.pkl
# Out:
# 07/19 09:20:21 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 911515986
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %% [markdown]
# epoch 60

# %%
# !python tools/train.py configs/recognition/swin/swin-base-kinetics400-goosebumps-project-task-subclass.py \
    --resume ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass/best_acc_top1_epoch_14.pth \
    --work-dir ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass
# Out:
# 07/19 08:13:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1315426211
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %%
# %cp -r ../../../../../work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass/* \
    work_dirs/swin-base-kinetics400-goosebumps-project-task-subclass/
