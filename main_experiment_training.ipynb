# %% [markdown]
# # Configuration Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip show mmaction2
# Out:
# WARNING: Package(s) not found: mmaction2

# %%
# !pip install -U openmim

# %%
# !mim install mmengine
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 32.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 21.7 MB/s eta 0:00:00
# ...

# %%
# !mim install mmcv
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 MB 6.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2
# Out:
# /content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2

# %%
# !pip install -v -e .
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-lg7dq9hz/mmaction2.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-lg7dq9hz/mmaction2.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-lg7dq9hz/mmaction2.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for decord>=0.4.1 from https://files.pythonhosted.org/packages/11/79/936af42edf90a7bd4e41a6cac89c913d4b47fa48a26b042d5129a9242ee3/decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata
# ...
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/44/5a/f0b9ad6c0a9017e62d4735daaeb11ba3b6c009d69a26141b258cd37b5588/einops-0.8.0-py3-none-any.whl.metadata
# ...

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 80.1 MB/s eta 0:00:00
# ...

# %%
# %cd ..

# %%
# !pip show mmaction2

# %%
# %cd mmaction2
# Out:
# D:\jupyterNotebook\C8099\Project\mmaction2

# %%
# %cd ..

# %%
# !pip install moviepy

# %% [markdown]
# # Training

# %% [markdown]
# # Task normal

# %% [markdown]
# ## base

# %%
# %cd mmaction2
# Out:
# [Errno 2] No such file or directory: 'mmaction2'
# /content/drive/MyDrive/Colab_Projects/CSC8099/mmaction2

# %% [markdown]
# var batch 1

# %%
# !python tools/train.py configs/recognition/swin/swin-base-goosebumps-project-task-normal.py \
    --work-dir ../../../../../work_dirs/swin-base-goosebumps-project-task-normal
# Out:
# 07/31 22:12:54 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 494575011
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-goosebumps-project-task-normal.py \
    ../../../../../work_dirs/swin-base-goosebumps-project-task-normal/best_acc_top1_epoch_31.pth \
    --dump ../../../../../work_dirs/swin-base-goosebumps-project-task-normal/results_best_acc_top1_epoch_31.pkl
# Out:
# 08/01 00:32:27 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1700993631
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-goosebumps-project-task-normal.py \
    ../../../../../work_dirs/swin-base-goosebumps-project-task-normal/best_acc_top1_epoch_20.pth \
    --dump ../../../../../work_dirs/swin-base-goosebumps-project-task-normal/best_acc_top1_epoch_20.pkl
# Out:
# 07/30 17:54:25 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1766876653
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# %cp -r ../../../../../work_dirs/swin-base-goosebumps-project-task-normal/* \
    work_dirs/swin-base-goosebumps-project-task-normal-eval-801/

# %% [markdown]
# var batch 8

# %%
# !python tools/train.py configs/recognition/swin/swin-base-goosebumps-project-task-normal.py \
    --work-dir ../../../../../work_dirs/swin-base-goosebumps-project-task-normal-batch-8
# Out:
# 08/01 12:39:19 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 914106835
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-goosebumps-project-task-normal.py \
    ../../../../../work_dirs/swin-base-goosebumps-project-task-normal-batch-8/best_acc_top1_epoch_28.pth \
    --dump ../../../../../work_dirs/swin-base-goosebumps-project-task-normal-batch-8/result_best_acc_top1_epoch_28.pkl
# Out:
# 08/01 14:57:07 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 388466546
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %%
# %cp -r ../../../../../work_dirs/swin-base-goosebumps-project-task-normal-batch-8/* \
    work_dirs/swin-base-goosebumps-project-task-normal-batch-8-801/

# %% [markdown]
# # Task subclass

# %% [markdown]
# ## base

# %% [markdown]
# var batch 1

# %%
# !python tools/train.py configs/recognition/swin/swin-base-goosebumps-project-task-subclass.py \
    --work-dir ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass
# Out:
# 08/01 09:26:22 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 868741509
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-goosebumps-project-task-subclass.py \
    ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/best_acc_top1_epoch_27.pth \
    --dump ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/results_best_acc_top1epoch_27.pkl
# Out:
# 08/01 10:43:54 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1960473904
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %% [markdown]
# var batch 8

# %%
# !python tools/train.py configs/recognition/swin/swin-base-goosebumps-project-task-subclass.py \
    --work-dir ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass
# Out:
# 08/02 19:02:46 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1954982906
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-goosebumps-project-task-subclass.py \
    ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/best_acc_top1_epoch_31.pth \
    --dump ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/result_best_acc_top1_epoch_31.pkl
# Out:
# 08/02 20:30:00 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 624591351
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
# ...

# %%
# !python tools/test.py configs/recognition/swin/swin-base-goosebumps-project-task-subclass.py \
    ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/epoch_36.pth \
    --dump ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/result_epoch_36.pkl
# Out:
# 08/01 12:28:56 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 988769638
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# ...

# %%
# %cp -r ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass/* \
    work_dirs/swin-base-goosebumps-project-task-subclass-eval-801/

# %% [markdown]
# ## batch 4

# %%
# !python tools/train.py configs/recognition/swin/swin-base-goosebumps-project-task-subclass.py \
    --work-dir ../../../../../work_dirs/swin-base-goosebumps-project-task-subclass
